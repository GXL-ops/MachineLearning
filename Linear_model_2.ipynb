# %%
# 多元线性回归
# 生成训练数据
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import tensorflow as tf
import matplotlib.pyplot as plt
# 绘制三维图像
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

learning_rate=0.5
training_epochs=1000
# 打印内容不限长度
# np.set_printoptions(threshold='nan')
# 构造数据
_x_data=np.float32(np.random.rand(2,100))
_y_data=np.dot(np.float32([0.100,0.200]),_x_data)+0.300
# 绘制三维散点图
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
# c表示颜色
ax.scatter(_x_data[0][:99],_x_data[1][:99],_y_data[:99],c='r')
ax.set_zlabel('Z')
ax.set_ylabel('Y')
ax.set_xlabel('X')
plt.show()
plt.close()

# %%
# 定义训练模型
x=tf.placeholder(tf.float32,[None,None],name='x')
y=tf.placeholder(tf.float32,[None,None],name='y')
W=tf.Variable(tf.random_uniform([1,2],-1.0,1.0))
b=tf.Variable(tf.zeros([1]))
# 二元线性模型
y=tf.matmul(W,_x_data)+b
loss=tf.reduce_mean(tf.square(y-_y_data))
optimizer=tf.train.GradientDescentOptimizer(learning_rate)
train=optimizer.minimize(loss)
init=tf.global_variables_initializer()

# %%
# 进行数据训练
with tf.Session() as sess:
    sess.run(init)
    for step in range(1,training_epochs):
        sess.run(train)
        preW=sess.run(W)
        preb=sess.run(b)
        if step%20==0:
            print(step,'\n',preW[0][0],preW[0][1],'\n',preb[0])
plt.close()
# Out:
# 20
#  0.2835395 0.120344244
#  0.25065362
# 40
#  0.13832481 0.18474877
#  0.28889644
# 60
#  0.10803732 0.19719635
#  0.29744285
# 80
#  0.1016955 0.19952089
#  0.29939553
# 100
#  0.10036048 0.19992991
#  0.2998531
# 120
#  0.10007745 0.19999386
#  0.2999633
# 140
#  0.100016855 0.20000114
#  0.2999906
# 160
#  0.100003734 0.20000094
#  0.29999754
# 180
#  0.10000086 0.20000039
#  0.29999936
# 200
#  0.10000022 0.20000014
#  0.29999983
# 220
#  0.10000008 0.20000008
#  0.29999992
# 240
#  0.10000008 0.20000008
#  0.29999992
# 260
#  0.10000008 0.20000008
#  0.29999992
# 280
#  0.10000008 0.20000008
#  0.29999992
# 300
#  0.10000008 0.20000008
#  0.29999992
# 320
#  0.10000008 0.20000008
#  0.29999992
# 340
#  0.10000008 0.20000008
#  0.29999992
# 360
#  0.10000008 0.20000008
#  0.29999992
# 380
#  0.10000008 0.20000008
#  0.29999992
# 400
#  0.10000008 0.20000008
#  0.29999992
# 420
#  0.10000008 0.20000008
#  0.29999992
# 440
#  0.10000008 0.20000008
#  0.29999992
# 460
# ...
